# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your data
df = pd.read_excel('data.xlsx')

# The correct column names based on your data output
columns_to_convert = [
    'loan_default', 
    'NEW.ACCTS.IN.LAST.SIX.MONTHS',
    'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
    'AVERAGE.ACCT.AGE',
    'NO.OF_INQUIRIES'
]

# Ensure the columns are numeric
for col in columns_to_convert:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Compute the correlation matrix for the selected columns
corr_matrix = df[columns_to_convert].corr()

# Print the correlation matrix
print(corr_matrix)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()
# Out:
#                                      loan_default  \
# loan_default                             1.000000
# NEW.ACCTS.IN.LAST.SIX.MONTHS            -0.029400
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS      0.034462
# AVERAGE.ACCT.AGE                              NaN
# NO.OF_INQUIRIES                          0.043678
#
#                                      NEW.ACCTS.IN.LAST.SIX.MONTHS  \
# loan_default                                            -0.029400
# NEW.ACCTS.IN.LAST.SIX.MONTHS                             1.000000
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS                      0.182769
# AVERAGE.ACCT.AGE                                              NaN
# NO.OF_INQUIRIES                                          0.264709
#
#                                      DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS  \
# loan_default                                                    0.034462
# NEW.ACCTS.IN.LAST.SIX.MONTHS                                    0.182769
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS                             1.000000
# AVERAGE.ACCT.AGE                                                     NaN
# NO.OF_INQUIRIES                                                 0.070715
#
#                                      AVERAGE.ACCT.AGE  NO.OF_INQUIRIES
# loan_default                                      NaN         0.043678
# NEW.ACCTS.IN.LAST.SIX.MONTHS                      NaN         0.264709
# DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS               NaN         0.070715
# AVERAGE.ACCT.AGE                                  NaN              NaN
# NO.OF_INQUIRIES                                   NaN         1.000000
